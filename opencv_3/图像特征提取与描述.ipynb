# %%
#Harris 角点检测
import cv2
import numpy as np
img=cv2.imread('../images/qipu.jpg')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray=np.float32(gray)
dst=cv2.cornerHarris(gray,2,3,0,0.04)
dst=cv2.dilate(dst,None)
img[dst>0.01*dst.max()]=[0,0,255]
cv2.imshow('dst',img)
if cv2.waitKey(0)&0xff==27:
    cv2.destroyAllWindows()

# %%
#亚像素级精确度的角点
#cv2.cornerSubPix()

# %%
#Shi-Tomasi 角点检测 
#cv2.goodFeatureToTrack()
import cv2
import numpy as np
from matplotlib import pyplot as plt
img=cv2.imread('../images/29.jpg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
corners=cv2.goodFeaturesToTrack(gray,25,0.1,34)
corners=np.int0(corners)

for i in corners:
    x,y=i.ravel()
    cv2.circle(img,(x,y),3,255,-1)
plt.imshow(img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f91bd14a048>, None)
